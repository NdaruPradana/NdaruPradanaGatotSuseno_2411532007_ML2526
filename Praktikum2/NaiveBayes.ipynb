# %% [markdown]
# <a href="https://colab.research.google.com/github/NdaruPradana/NdaruPradanaGatotSuseno_2411532007_ML2526/blob/main/Praktikum2/NaiveBayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import seaborn as sns
sns.set_style("darkgrid")

# %%
dataset_url = 'https://raw.githubusercontent.com/NdaruPradana/NdaruPradanaGatotSuseno_2411532007_ML2526/refs/heads/main/Praktikum2/Breast_cancer_data.csv'
data = pd.read_csv(dataset_url)
data.head()
# Out:
#    mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    diagnosis
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
data.tail()
# Out:
#      mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness  \
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      diagnosis
# 564          0
# 565          0
# 566          0
# 567          0
# 568          1

# %%
data["diagnosis"].hist()
# Out:
# <Axes: >

# %%
# Prepare features (X) and target (y)
X, y = data.drop(columns='diagnosis'), data['diagnosis']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=41)

# %%
from sklearn.naive_bayes import GaussianNB

# Initialize and train the Gaussian Naive Bayes model
sklearn_gnb = GaussianNB()
sklearn_gnb.fit(X_train, y_train)

# Make predictions on the test set
y_pred = sklearn_gnb.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, ConfusionMatrixDisplay

print('Sklearn Akurasi = ', accuracy_score(y_test, y_pred))
print('Sklearn F1-Score = ', f1_score(y_test, y_pred))

# Definisikan label kelas
labels = ['B', 'M']

# Display confusion matrix
cm_sklearn = confusion_matrix(y_test, y_pred)
disp_sklearn = ConfusionMatrixDisplay(confusion_matrix=cm_sklearn, display_labels=labels)

disp_sklearn.plot()
plt.title('Confusion Matrix (Sklearn Gaussian Naive Bayes)')
plt.show()
# Out:
# Sklearn Akurasi =  0.9473684210526315
# Sklearn F1-Score =  0.96
